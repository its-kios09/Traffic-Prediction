# %% [markdown]
# #### 1.0 import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import pickle
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-03-23 22:07:45.197852: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 1.1 Loading the Traffic data and Viewing the top 5 of the dataset
# This dataset is a collection of numbers of vehicles at four junctions at an hourly frequency. The CSV file provides four features:
#    - Date time
#    - Junctions
#    - Vehicles
#    - ID
#
# The sensors on each of these junctions were collecting data at different times, hence the traffic data from different time periods. Some of the junctions have provided limited or sparse data.

# %%
df =pd.read_csv('../Dataset/traffic.csv')
df.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %% [markdown]
# #### 1.3 Data Exploration
#    - Pharsing dates
#    - Ploting time series
#    - Feature Engineering for EDA

# %%
# Pharsing dates
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Dropping the ID column
df = df.drop(['ID'], axis=1)

# Viewing the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# #### 1.4 Exploratory Data Analysis

# %%
# Passing a list of colors to be used for 
colors = ['#FFD4DB', '#BBE7FE','#D3B5E5','#DFE2DB']
# Ploting the Timeseries
plt.figure(figsize=(20,4) , facecolor='#627D78')
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)

# labelling the axes
Time_series.set_title("Traffic On Juctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# #### Expected output: Noticeable information in the above plot:
#     - It can be seen here that the first junction is visibly having an upward trend.
#     - The data for the fourth junction is sparse starting only after 2017
#     - Seasonality is not evident from the above plot, So we must explore datetime composition to figure out more about it.

# %% [markdown]
# #### 1.5 Feature Engineering
#     - Year
#     - Month
#     - Date in the given month
#     - Hour

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %% [markdown]
# #### 1.5 Exploratory Data Analysis
#     - Plotting the newly created features

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ##### From the above plot following things can be concluded:
#
# - Yearly, there has been an upward trend for all junctions except for the fourth junction. As we already established above that the fourth junction has limited data and that don't span over a year.
#
# - We can see that there is an influx in the first and second junctions around June. I presume this may be due to summer break and activities around the same.
#
# - Monthly, throughout all the dates there is a good consistency in data.
#
# - For a day, we can see that are peaks during morning and evening times and a decline during night hours. This is as per expectation.
#
# - For weekly patterns, Sundays enjoy smoother traffic as there are lesser vehicles on roads. Whereas Monday to Friday the traffic is steady.

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# #### The count plot shows that there is an increase in the number of vehicles between 2015 and 2016. However, it is inconclusive to say the same about 2017 as we have limited data for 2017 ie till the 7th month.

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# <Axes: >

# %% [markdown]
# ###### The highest correlation is certainly with the preexisting feature.
#
# I will conclude my EDA with a pair plot. It's an interesting overall representation of any data.

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %% [markdown]
# ##### Conclusions that I have come to draw after this EDA
#
# - The span of data from all four junctions is not the same. Data provided for the fourth junction is limited to only 2017.
# - The yearly trend for Junctions one, two and three have diffrent slopes.
#
# Junction number one has a more strong weekly seasonality in comparison to the other junctions.
# For the above-postulated reasons, I think that junctions must be transformed as per their individual needs.

# %% [markdown]
# #### 1.6 Data Transformation and Preprocessing

# %% [markdown]
# #### In this step I will be following the subsequent order:
#
# - Creating different frames for each Junction and plotting them
# - Transforming the series and plotting them
# - Performing the Augmented Dickey-Fuller test to check the seasonality of transformed series
# - Creating test and train sets

# %%
#Pivoting data fron junction 
df_J = df.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles                                                   Year  \
# Junction             1             2             3            4             1
# count     14592.000000  14592.000000  14592.000000  4344.000000  14592.000000
# mean         45.052906     14.253221     13.694010     7.251611   2016.197368
# std          23.008345      7.401307     10.436005     3.521455      0.599247
# min           5.000000      1.000000      1.000000     1.000000   2015.000000
# 25%          27.000000      9.000000      7.000000     5.000000   2016.000000
# 50%          40.000000     13.000000     11.000000     7.000000   2016.000000
# 75%          59.000000     17.000000     18.000000     9.000000   2017.000000
# max         156.000000     48.000000    180.000000    36.000000   2017.000000
#
#                                                      Month                \
# Junction             2             3       4             1             2
# count     14592.000000  14592.000000  4344.0  14592.000000  14592.000000
# mean       2016.197368   2016.197368  2017.0      6.120066      6.120066
# std           0.599247      0.599247     0.0      3.619842      3.619842
# min        2015.000000   2015.000000  2017.0      1.000000      1.000000
# 25%        2016.000000   2016.000000  2017.0      3.000000      3.000000
# 50%        2016.000000   2016.000000  2017.0      6.000000      6.000000
# 75%        2017.000000   2017.000000  2017.0     10.000000     10.000000
# max        2017.000000   2017.000000  2017.0     12.000000     12.000000
#
#                                           Date_no                              \
# Junction             3            4             1             2             3
# count     14592.000000  4344.000000  14592.000000  14592.000000  14592.000000
# mean          6.120066     3.508287     15.710526     15.710526     15.710526
# std           3.619842     1.710157      8.789036      8.789036      8.789036
# min           1.000000     1.000000      1.000000      1.000000      1.000000
# 25%           3.000000     2.000000      8.000000      8.000000      8.000000
# 50%           6.000000     4.000000     16.000000     16.000000     16.000000
# 75%          10.000000     5.000000     23.000000     23.000000     23.000000
# max          12.000000     6.000000     31.000000     31.000000     31.000000
#
#                                Hour
# Junction            4             1             2             3            4
# count     4344.000000  14592.000000  14592.000000  14592.000000  4344.000000
# mean        15.602210     11.500000     11.500000     11.500000    11.500000
# std          8.736328      6.922424      6.922424      6.922424     6.922983
# min          1.000000      0.000000      0.000000      0.000000     0.000000
# 25%          8.000000      5.750000      5.750000      5.750000     5.750000
# 50%         16.000000     11.500000     11.500000     11.500000    11.500000
# 75%         23.000000     17.250000     17.250000     17.250000    17.250000
# max         31.000000     23.000000     23.000000     23.000000    23.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %% [markdown]
# A time series is stationary if it does not have a trend or seasonality. However, in the EDA, we saw a weekly seasonality and an upwards trend over the years. In the above plot, it is again established that Junctions one and two have an upward trend. If we limit the span we will be able to further see the weekly seasonality. I will be spairing that step at this point and moving on with the respective transforms on datasets.
#
# ##### Steps for Transforming:
#
# - Normalizing
# - Differencing

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %% [markdown]
# In accordance with the above observations, Differencing to eliminate the seasonality should be performed as follows:
#
# - For Junction one, I will be taking a difference of weekly values.
# - For junction two, The difference of consecutive days is a better choice
# - For Junctions three and four, the difference of the hourly values will serve the purpose.

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %% [markdown]
# #### Plots of Transformed Dataframe

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %% [markdown]
# The plots above seem linear. To ensure they are Stationary I will be performing an Augmented Dickey-Fuller test.

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415548
# p-value: 4.798539876395171e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940133
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832824
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.979092563052266
# p-value: 2.7787875325955e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %% [markdown]
# #### Now that the data is stationary, preprocessing the data for the neural net by:
#
# - Splitting the test train sets
# - Assigning X as features and y as target
# - Reshaping data for neural net

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %% [markdown]
# #### 1.7 Model Building
# For this project, I have settled to use Gated Recurrent Unit (GRU). In this section, I am creating a function for the neural net to call on and fit the data frames for all four junctions.

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    # Save the trained model to a file
    model.save("gru_model.h5")

    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# #### 1.8 Fitting The Model
#
# Now, I will be fitting the transformed training sets of four junctions to the model created and compare them to the transformed test sets.
#
#
# ##### Fitting the first junction and plotting the predictions and testset

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# 2023-03-23 22:10:43.090717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 22:10:43.124832: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0779WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 112s 1s/step - loss: 0.0779
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0668WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 93s 1s/step - loss: 0.0668
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0643WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 96s 1s/step - loss: 0.0643
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0629WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 94s 1s/step - loss: 0.0629
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0620WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 88s 1s/step - loss: 0.0620
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0612WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 90s 1s/step - loss: 0.0612
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0600WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 91s 1s/step - loss: 0.0600
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0586WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 102s 1s/step - loss: 0.0586
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0577WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 92s 1s/step - loss: 0.0577
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0570WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 93s 1s/step - loss: 0.0570
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0565WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 99s 1s/step - loss: 0.0565
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 105s 1s/step - loss: 0.0562
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 101s 1s/step - loss: 0.0558
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 101s 1s/step - loss: 0.0562
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 101s 1s/step - loss: 0.0541
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 107s 1s/step - loss: 0.0541
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 101s 1s/step - loss: 0.0541
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0535WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 87s 1s/step - loss: 0.0535
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 100s 1s/step - loss: 0.0530
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 110s 1s/step - loss: 0.0523
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 105s 1s/step - loss: 0.0520
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 100s 1s/step - loss: 0.0514
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 113s 1s/step - loss: 0.0514
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 105s 1s/step - loss: 0.0513
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 122s 1s/step - loss: 0.0509
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 108s 1s/step - loss: 0.0508
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0504WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 103s 1s/step - loss: 0.0504
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0501WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 107s 1s/step - loss: 0.0501
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 97s 1s/step - loss: 0.0509
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0502WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 97s 1s/step - loss: 0.0502
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 96s 1s/step - loss: 0.0498
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 103s 1s/step - loss: 0.0500
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 111s 1s/step - loss: 0.0497
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 111s 1s/step - loss: 0.0498
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 95s 1s/step - loss: 0.0494
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 79s 911ms/step - loss: 0.0490
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 529ms/step - loss: 0.0488
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 64s 738ms/step - loss: 0.0498
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 62s 717ms/step - loss: 0.0493
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 62s 716ms/step - loss: 0.0487
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 64s 734ms/step - loss: 0.0488
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 85s 984ms/step - loss: 0.0484
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 86s 987ms/step - loss: 0.0481
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 84s 960ms/step - loss: 0.0486
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 95s 1s/step - loss: 0.0483
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 103s 1s/step - loss: 0.0488
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 100s 1s/step - loss: 0.0482
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 96s 1s/step - loss: 0.0483
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 86s 989ms/step - loss: 0.0480
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 81s 934ms/step - loss: 0.0480
# 45/45 [==============================] - 10s 148ms/step

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.24745522059281042.

# %% [markdown]
# #### 1.9 Fitting the Second Junction and Plotting the Predictions and testset

# %%
# Prediction for Second Junction
PredJ2 = GRU_model(X_trainJ2, y_trainJ2, X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2345WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 99s 956ms/step - loss: 0.2345
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2046WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 89s 1s/step - loss: 0.2046
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1993WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 81s 925ms/step - loss: 0.1993
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 84s 957ms/step - loss: 0.1938
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1951WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 99s 1s/step - loss: 0.1951
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1912WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 84s 959ms/step - loss: 0.1912
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1901WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 87s 983ms/step - loss: 0.1901
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1919WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 85s 960ms/step - loss: 0.1919
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1879WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 90s 1s/step - loss: 0.1879
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 86s 974ms/step - loss: 0.1900
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 85s 970ms/step - loss: 0.1897
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1893WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 86s 977ms/step - loss: 0.1893
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 86s 980ms/step - loss: 0.1872
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1885WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 85s 961ms/step - loss: 0.1885
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 102s 1s/step - loss: 0.1873
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1888
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1859
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1871
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 94s 1s/step - loss: 0.1859
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1858
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1851WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1851
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1847WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1847
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1837WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 96s 1s/step - loss: 0.1837
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 94s 1s/step - loss: 0.1859
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 105s 1s/step - loss: 0.1857
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1851WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1851
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1839
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1833
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1847WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 98s 1s/step - loss: 0.1847
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 94s 1s/step - loss: 0.1845
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1833
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 96s 1s/step - loss: 0.1852
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 94s 1s/step - loss: 0.1839
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 105s 1s/step - loss: 0.1829
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1823WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 96s 1s/step - loss: 0.1823
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 91s 1s/step - loss: 0.1830
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1835
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1819
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1826
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1846
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1838
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 92s 1s/step - loss: 0.1824
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.1831
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.1820
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 96s 1s/step - loss: 0.1816
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 91s 1s/step - loss: 0.1813
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 94s 1s/step - loss: 0.1810
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1820
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 96s 1s/step - loss: 0.1816
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1816
# 45/45 [==============================] - 12s 195ms/step

# %%
# Results for J2
RMSE_J2 = RMSE_Value(y_testJ2, PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5532470110217274.

# %% [markdown]
# #### 2.0: Fitting the third junction and plotting the prediction and testset

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3024WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 109s 1s/step - loss: 0.3024
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.2933
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2912WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.2912
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 90s 1s/step - loss: 0.2903
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2885WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 60s 680ms/step - loss: 0.2885
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 61s 689ms/step - loss: 0.2880
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2904WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 64s 730ms/step - loss: 0.2904
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 60s 679ms/step - loss: 0.2869
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2907WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 55s 626ms/step - loss: 0.2907
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 662ms/step - loss: 0.2862
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 59s 666ms/step - loss: 0.2872
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 57s 648ms/step - loss: 0.2835
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 701ms/step - loss: 0.2846
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 657ms/step - loss: 0.2812
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 656ms/step - loss: 0.2812
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2791WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 59s 672ms/step - loss: 0.2791
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2800WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 69s 788ms/step - loss: 0.2800
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2790WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 56s 641ms/step - loss: 0.2790
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2742WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 57s 653ms/step - loss: 0.2742
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 61s 701ms/step - loss: 0.2750
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2777WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 702ms/step - loss: 0.2777
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2753WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 66s 747ms/step - loss: 0.2753
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 64s 731ms/step - loss: 0.2759
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2747WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 703ms/step - loss: 0.2747
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2710WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 653ms/step - loss: 0.2710
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 61s 689ms/step - loss: 0.2759
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2773WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 59s 669ms/step - loss: 0.2773
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 65s 742ms/step - loss: 0.2727
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 53s 601ms/step - loss: 0.2737
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 55s 623ms/step - loss: 0.2737
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 666ms/step - loss: 0.2727
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2716
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 665ms/step - loss: 0.2719
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2715WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 54s 612ms/step - loss: 0.2715
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 57s 644ms/step - loss: 0.2698
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2725WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 60s 677ms/step - loss: 0.2725
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 654ms/step - loss: 0.2698
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 60s 684ms/step - loss: 0.2686
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 55s 625ms/step - loss: 0.2685
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 56s 638ms/step - loss: 0.2690
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 55s 631ms/step - loss: 0.2687
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 59s 675ms/step - loss: 0.2691
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2669WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 662ms/step - loss: 0.2669
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 57s 642ms/step - loss: 0.2684
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 653ms/step - loss: 0.2656
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2662WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 662ms/step - loss: 0.2662
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 66s 748ms/step - loss: 0.2661
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2652WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 58s 658ms/step - loss: 0.2652
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 702ms/step - loss: 0.2644
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2666WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 65s 735ms/step - loss: 0.2666
# 45/45 [==============================] - 8s 108ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6118998879339992.

# %% [markdown]
# #### 2.1

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6910WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 31s 762ms/step - loss: 0.6910
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 605ms/step - loss: 0.6886
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6879WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 648ms/step - loss: 0.6879
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6895WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 667ms/step - loss: 0.6895
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6851WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 609ms/step - loss: 0.6851
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 765ms/step - loss: 0.6838
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 741ms/step - loss: 0.6850
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 707ms/step - loss: 0.6839
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6881WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 667ms/step - loss: 0.6881
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 708ms/step - loss: 0.6840
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6791WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 697ms/step - loss: 0.6791
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6761WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 767ms/step - loss: 0.6761
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6784WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 690ms/step - loss: 0.6784
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6742WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 693ms/step - loss: 0.6742
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 609ms/step - loss: 0.6795
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 691ms/step - loss: 0.6766
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6792WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 699ms/step - loss: 0.6792
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 605ms/step - loss: 0.6810
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 658ms/step - loss: 0.6766
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6731WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 15s 566ms/step - loss: 0.6731
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 14s 552ms/step - loss: 0.6727
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6717WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 633ms/step - loss: 0.6717
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 693ms/step - loss: 0.6781
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6711WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 728ms/step - loss: 0.6711
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6717WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 703ms/step - loss: 0.6717
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6744WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 610ms/step - loss: 0.6744
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6679WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 649ms/step - loss: 0.6679
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6620WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 724ms/step - loss: 0.6620
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6643WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 671ms/step - loss: 0.6643
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6611WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 748ms/step - loss: 0.6611
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6539WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 724ms/step - loss: 0.6539
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6536WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 747ms/step - loss: 0.6536
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6455WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 731ms/step - loss: 0.6455
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6504WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 748ms/step - loss: 0.6504
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6445WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 15s 585ms/step - loss: 0.6445
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 601ms/step - loss: 0.6334
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 772ms/step - loss: 0.6284
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6506WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 25s 983ms/step - loss: 0.6506
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6288WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 685ms/step - loss: 0.6288
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6158WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 14s 556ms/step - loss: 0.6158
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6047WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 736ms/step - loss: 0.6047
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5944WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 624ms/step - loss: 0.5944
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5837WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 613ms/step - loss: 0.5837
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5756WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 659ms/step - loss: 0.5756
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5660WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 701ms/step - loss: 0.5660
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5605WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 643ms/step - loss: 0.5605
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 653ms/step - loss: 0.5520
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5463WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 637ms/step - loss: 0.5463
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5373WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 16s 616ms/step - loss: 0.5373
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 764ms/step - loss: 0.5360
# 13/13 [==============================] - 4s 121ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
#       4 #Saving the model
# ----> 5 model.save("gru_model.h5")
#
# NameError: name 'model' is not defined

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)

# %% [markdown]
# #### 2.1 : Inversing the Transformation of data
#
# Applying inversing transformation to remove seasonality and trends, Performing this step will make the prediction back to accurate scale

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Predictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Predictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Predictions And Orignals For Junction 3", 2)

# %% [markdown]
# #### The inverse transform on the fourth junction

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Predictions And Orignals For Junction 4", 3)

# %% [markdown]
# #### Summary
#
# In this notebook, I have trained GRU Neural Network to Predict traffic on four junctions. I used Normalization and Differencing transformation to achieve a stationary time seriess. As the Junction varying in trends and seasonality, i took different approach for each junction to make it stationary. I applied the root mean squared error as the evalution metric for the model. In addition to that, i have plotted the Prediction alongside the original test value.Take aways from the data analysis;
#
# The number of vehicles in junction one is rising more rapidly compared to junction two and three. The Sparsity of the data in junction four bars me from making any conclusion on the same
#
# The junction one's traffic has a stronger weekly seasonlity as well as hourly seasonality. Where as other junction are significantly linear
